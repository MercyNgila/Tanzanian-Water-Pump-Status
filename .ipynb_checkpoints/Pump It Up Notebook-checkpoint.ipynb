# %% [markdown]
# # 1. Introduction

# %% [markdown]
# In this Project, I will complete a machine learning workflow using classification solutions, including data preparation, modeling (including hyperparameter tuning), and final model evaluation.

# %% [markdown]
# ## 1.1. Business Understanding

# %% [markdown]
# Your goal is to predict the operating condition of a waterpoint for each record in the dataset.
#
# Using data from Taarifa and the Tanzanian Ministry of Water, can you predict which pumps are functional, which need some repairs, and which don't work at all? Predict one of these three classes based on a number of variables about what kind of pump is operating, when it was installed, and how it is managed. A smart understanding of which waterpoints will fail can improve maintenance operations and ensure that clean, potable water is available to communities across Tanzania.

# %% [markdown]
# ## 2.2. Objectives

# %% [markdown]
# - jdnlknlknblkn
# - nnlrnknklnknm
# - jnnklnk;m;lm;lm;lm
# - njbnjnknkmnkm;lm

# %% [markdown]
# # 2. Requirements

# %% [markdown]
# - Loading Notebook Libraries
# - Loading Dataset
# - Explore Dataset
# - Data Cleaning
# - Analysing Preprocessing

# %% [markdown]
# # 3. Data Understanding

# %% [markdown]
# The data for this project comes from the Taarifa waterpoints dashboard, which aggregates data from the Tanzania Ministry of Water.
#
# Taarifa is an open source platform for the crowd sourced reporting and triaging of infrastructure related issues.
#
# There are three datasets for this project:
# - Test set values (14850 rows × 40 columns)
# - Training set labels (59400 rows × 40 columns)
# - Training set values (59400 rows × 40 columns)

# %% [markdown]
# ## 2.1 Loading Libraries

# %%
#load relevant libraries
import pandas as pd
import matplotlib.pyplot as plt
# %matplotlib inline
import seaborn as sns
import warnings
warnings.simplefilter("ignore")

# %% [markdown]
# ## 2.2 Loading Datasets

# %%
# Loading datasets
train_values = pd.read_csv('training set.csv')
train_labels = pd.read_csv('training set.csv')
test_values = pd.read_csv('test set.csv')

# %% [markdown]
# ## 2.3 Explore dataframes

# %%
train_values.head(3)
# Out:
#       id  amount_tsh date_recorded        funder  gps_height     installer  \
# 0  69572      6000.0    2011-03-14         Roman        1390         Roman
# 1   8776         0.0    2013-03-06       Grumeti        1399       GRUMETI
# 2  34310        25.0    2013-02-25  Lottery Club         686  World vision
#
#    longitude  latitude     wpt_name  num_private  ... payment_type  \
# 0  34.938093 -9.856322         none            0  ...     annually
# 1  34.698766 -2.147466     Zahanati            0  ...    never pay
# 2  37.460664 -3.821329  Kwa Mahundi            0  ...   per bucket
#
#   water_quality quality_group      quantity  quantity_group  \
# 0          soft          good        enough          enough
# 1          soft          good  insufficient    insufficient
# 2          soft          good        enough          enough
#
#                  source           source_type  source_class  \
# 0                spring                spring   groundwater
# 1  rainwater harvesting  rainwater harvesting       surface
# 2                   dam                   dam       surface
#
#                waterpoint_type waterpoint_type_group
# 0           communal standpipe    communal standpipe
# 1           communal standpipe    communal standpipe
# 2  communal standpipe multiple    communal standpipe
#
# [3 rows x 40 columns]

# %%
train_labels.head(3)
# Out:
#       id  amount_tsh date_recorded        funder  gps_height     installer  \
# 0  69572      6000.0    2011-03-14         Roman        1390         Roman
# 1   8776         0.0    2013-03-06       Grumeti        1399       GRUMETI
# 2  34310        25.0    2013-02-25  Lottery Club         686  World vision
#
#    longitude  latitude     wpt_name  num_private  ... payment_type  \
# 0  34.938093 -9.856322         none            0  ...     annually
# 1  34.698766 -2.147466     Zahanati            0  ...    never pay
# 2  37.460664 -3.821329  Kwa Mahundi            0  ...   per bucket
#
#   water_quality quality_group      quantity  quantity_group  \
# 0          soft          good        enough          enough
# 1          soft          good  insufficient    insufficient
# 2          soft          good        enough          enough
#
#                  source           source_type  source_class  \
# 0                spring                spring   groundwater
# 1  rainwater harvesting  rainwater harvesting       surface
# 2                   dam                   dam       surface
#
#                waterpoint_type waterpoint_type_group
# 0           communal standpipe    communal standpipe
# 1           communal standpipe    communal standpipe
# 2  communal standpipe multiple    communal standpipe
#
# [3 rows x 40 columns]

# %%
test_values.head(3)
# Out:
#       id  amount_tsh date_recorded                  funder  gps_height  \
# 0  50785         0.0    2013-02-04                    Dmdd        1996
# 1  51630         0.0    2013-02-04  Government Of Tanzania        1569
# 2  17168         0.0    2013-02-01                     NaN        1567
#
#   installer  longitude  latitude                 wpt_name  num_private  ...  \
# 0      DMDD  35.290799 -4.059696  Dinamu Secondary School            0  ...
# 1       DWE  36.656709 -3.309214                  Kimnyak            0  ...
# 2       NaN  34.767863 -5.004344           Puma Secondary            0  ...
#
#   payment_type water_quality quality_group      quantity  quantity_group  \
# 0    never pay          soft          good      seasonal        seasonal
# 1    never pay          soft          good  insufficient    insufficient
# 2    never pay          soft          good  insufficient    insufficient
#
#                  source           source_type  source_class  \
# 0  rainwater harvesting  rainwater harvesting       surface
# 1                spring                spring   groundwater
# 2  rainwater harvesting  rainwater harvesting       surface
#
#       waterpoint_type waterpoint_type_group
# 0               other                 other
# 1  communal standpipe    communal standpipe
# 2               other                 other
#
# [3 rows x 40 columns]

# %% [markdown]
# #### Observation
#
# - I will need to merge train values and train labels.
#
# - The id column seems to be a unique identifier so I will make it and index column for both train and test dataframe

# %%
# Set id column as index column
test = test_values
test.set_index('id', inplace = True)
test.head()
# Out:
#        amount_tsh date_recorded                  funder  gps_height  \
# id
# 50785         0.0    2013-02-04                    Dmdd        1996
# 51630         0.0    2013-02-04  Government Of Tanzania        1569
# 17168         0.0    2013-02-01                     NaN        1567
# 45559         0.0    2013-01-22              Finn Water         267
# 49871       500.0    2013-03-27                  Bruder        1260
#
#         installer  longitude   latitude                 wpt_name  num_private  \
# id
# 50785        DMDD  35.290799  -4.059696  Dinamu Secondary School            0
# 51630         DWE  36.656709  -3.309214                  Kimnyak            0
# 17168         NaN  34.767863  -5.004344           Puma Secondary            0
# 45559  FINN WATER  38.058046  -9.418672           Kwa Mzee Pange            0
# 49871      BRUDER  35.006123 -10.950412          Kwa Mzee Turuka            0
#
#                          basin  ... payment_type water_quality  quality_group  \
# id                              ...
# 50785                 Internal  ...    never pay          soft           good
# 51630                  Pangani  ...    never pay          soft           good
# 17168                 Internal  ...    never pay          soft           good
# 45559  Ruvuma / Southern Coast  ...      unknown          soft           good
# 49871  Ruvuma / Southern Coast  ...      monthly          soft           good
#
#            quantity quantity_group                source  \
# id
# 50785      seasonal       seasonal  rainwater harvesting
# 51630  insufficient   insufficient                spring
# 17168  insufficient   insufficient  rainwater harvesting
# 45559           dry            dry          shallow well
# 49871        enough         enough                spring
#
#                 source_type source_class     waterpoint_type  \
# id
# 50785  rainwater harvesting      surface               other
# 51630                spring  groundwater  communal standpipe
# 17168  rainwater harvesting      surface               other
# 45559          shallow well  groundwater               other
# 49871                spring  groundwater  communal standpipe
#
#       waterpoint_type_group
# id
# 50785                 other
# 51630    communal standpipe
# 17168                 other
# 45559                 other
# 49871    communal standpipe
#
# [5 rows x 39 columns]

# %%
# Merge train values and train labels dataframes
train = train_values.merge(train_labels, how='inner')
train.head()
# Out:
#       id  amount_tsh date_recorded        funder  gps_height     installer  \
# 0  69572      6000.0    2011-03-14         Roman        1390         Roman
# 1   8776         0.0    2013-03-06       Grumeti        1399       GRUMETI
# 2  34310        25.0    2013-02-25  Lottery Club         686  World vision
# 3  67743         0.0    2013-01-28        Unicef         263        UNICEF
# 4  19728         0.0    2011-07-13   Action In A           0       Artisan
#
#    longitude   latitude              wpt_name  num_private  ... payment_type  \
# 0  34.938093  -9.856322                  none            0  ...     annually
# 1  34.698766  -2.147466              Zahanati            0  ...    never pay
# 2  37.460664  -3.821329           Kwa Mahundi            0  ...   per bucket
# 3  38.486161 -11.155298  Zahanati Ya Nanyumbu            0  ...    never pay
# 4  31.130847  -1.825359               Shuleni            0  ...    never pay
#
#   water_quality quality_group      quantity  quantity_group  \
# 0          soft          good        enough          enough
# 1          soft          good  insufficient    insufficient
# 2          soft          good        enough          enough
# 3          soft          good           dry             dry
# 4          soft          good      seasonal        seasonal
#
#                  source           source_type  source_class  \
# 0                spring                spring   groundwater
# 1  rainwater harvesting  rainwater harvesting       surface
# 2                   dam                   dam       surface
# 3           machine dbh              borehole   groundwater
# 4  rainwater harvesting  rainwater harvesting       surface
#
#                waterpoint_type waterpoint_type_group
# 0           communal standpipe    communal standpipe
# 1           communal standpipe    communal standpipe
# 2  communal standpipe multiple    communal standpipe
# 3  communal standpipe multiple    communal standpipe
# 4           communal standpipe    communal standpipe
#
# [5 rows x 40 columns]

# %%
# expanding the number of visible columns

pd.set_option('display.max_columns', 30)

# %%
#  Set id as index column
train.set_index('id', inplace = True)
train.head(10)
# Out:
#        amount_tsh date_recorded               funder  gps_height  \
# id
# 69572      6000.0    2011-03-14                Roman        1390
# 8776          0.0    2013-03-06              Grumeti        1399
# 34310        25.0    2013-02-25         Lottery Club         686
# 67743         0.0    2013-01-28               Unicef         263
# 19728         0.0    2011-07-13          Action In A           0
# 9944         20.0    2011-03-13  Mkinga Distric Coun           0
# 19816         0.0    2012-10-01                 Dwsp           0
# 54551         0.0    2012-10-09                Rwssp           0
# 53934         0.0    2012-11-03             Wateraid           0
# 46144         0.0    2011-08-03          Isingiro Ho           0
#
#           installer  longitude   latitude              wpt_name  num_private  \
# id
# 69572         Roman  34.938093  -9.856322                  none            0
# 8776        GRUMETI  34.698766  -2.147466              Zahanati            0
# 34310  World vision  37.460664  -3.821329           Kwa Mahundi            0
# 67743        UNICEF  38.486161 -11.155298  Zahanati Ya Nanyumbu            0
# 19728       Artisan  31.130847  -1.825359               Shuleni            0
# 9944            DWE  39.172796  -4.765587                Tajiri            0
# 19816          DWSP  33.362410  -3.766365            Kwa Ngomho            0
# 54551           DWE  32.620617  -4.226198          Tushirikiane            0
# 53934     Water Aid  32.711100  -5.146712     Kwa Ramadhan Musa            0
# 46144       Artisan  30.626991  -1.257051               Kwapeto            0
#
#                          basin       subvillage     region  region_code  \
# id
# 69572               Lake Nyasa         Mnyusi B     Iringa           11
# 8776             Lake Victoria          Nyamara       Mara           20
# 34310                  Pangani          Majengo    Manyara           21
# 67743  Ruvuma / Southern Coast       Mahakamani     Mtwara           90
# 19728            Lake Victoria       Kyanyamisa     Kagera           18
# 9944                   Pangani      Moa/Mwereme      Tanga            4
# 19816                 Internal    Ishinabulandi  Shinyanga           17
# 54551          Lake Tanganyika  Nyawishi Center  Shinyanga           17
# 53934          Lake Tanganyika       Imalauduki     Tabora           14
# 46144            Lake Victoria         Mkonomre     Kagera           18
#
#        district_code              lga  ... extraction_type_group  \
# id                                     ...
# 69572              5           Ludewa  ...               gravity
# 8776               2        Serengeti  ...               gravity
# 34310              4        Simanjiro  ...               gravity
# 67743             63         Nanyumbu  ...           submersible
# 19728              1          Karagwe  ...               gravity
# 9944               8           Mkinga  ...           submersible
# 19816              3  Shinyanga Rural  ...                swn 80
# 54551              3           Kahama  ...           nira/tanira
# 53934              6     Tabora Urban  ...         india mark ii
# 46144              1          Karagwe  ...           nira/tanira
#
#        extraction_type_class management management_group         payment  \
# id
# 69572                gravity        vwc       user-group    pay annually
# 8776                 gravity        wug       user-group       never pay
# 34310                gravity        vwc       user-group  pay per bucket
# 67743            submersible        vwc       user-group       never pay
# 19728                gravity      other            other       never pay
# 9944             submersible        vwc       user-group  pay per bucket
# 19816               handpump        vwc       user-group       never pay
# 54551               handpump        wug       user-group         unknown
# 53934               handpump        vwc       user-group       never pay
# 46144               handpump        vwc       user-group       never pay
#
#       payment_type water_quality  quality_group      quantity quantity_group  \
# id
# 69572     annually          soft           good        enough         enough
# 8776     never pay          soft           good  insufficient   insufficient
# 34310   per bucket          soft           good        enough         enough
# 67743    never pay          soft           good           dry            dry
# 19728    never pay          soft           good      seasonal       seasonal
# 9944    per bucket         salty          salty        enough         enough
# 19816    never pay          soft           good        enough         enough
# 54551      unknown         milky          milky        enough         enough
# 53934    never pay         salty          salty      seasonal       seasonal
# 46144    never pay          soft           good        enough         enough
#
#                      source           source_type source_class  \
# id
# 69572                spring                spring  groundwater
# 8776   rainwater harvesting  rainwater harvesting      surface
# 34310                   dam                   dam      surface
# 67743           machine dbh              borehole  groundwater
# 19728  rainwater harvesting  rainwater harvesting      surface
# 9944                  other                 other      unknown
# 19816           machine dbh              borehole  groundwater
# 54551          shallow well          shallow well  groundwater
# 53934           machine dbh              borehole  groundwater
# 46144          shallow well          shallow well  groundwater
#
#                    waterpoint_type waterpoint_type_group
# id
# 69572           communal standpipe    communal standpipe
# 8776            communal standpipe    communal standpipe
# 34310  communal standpipe multiple    communal standpipe
# 67743  communal standpipe multiple    communal standpipe
# 19728           communal standpipe    communal standpipe
# 9944   communal standpipe multiple    communal standpipe
# 19816                    hand pump             hand pump
# 54551                    hand pump             hand pump
# 53934                    hand pump             hand pump
# 46144                    hand pump             hand pump
#
# [10 rows x 39 columns]

# %% [markdown]
# ### Columns in the dataset
#
# - amount_tsh      - Total static head (amount water available to waterpoint)
# - date_recorded   - The date the row was entered
# - funder          - Who funded the well
# - gps_height      - Altitude of the well
# - installer       - Organization that installed the well
# - longitude       - GPS coordinate
# - latitude        - GPS coordinate
# - wpt_name        - Name of the waterpoint if there is one
# - num_private     -
# - basin           - Geographic water basin
# - subvillage      - Geographic location
# - region          - Geographic location
# - region_code     - Geographic location (coded)
# - district_code   - Geographic location (coded)
# - lga             - Geographic location
# - ward            - Geographic location
# - population      - Population around the well
# - public_meeting  - True/False
# - recorded_by     - Group entering this row of data
# - scheme_management     - Who operates the waterpoint
# - scheme_name           - Who operates the waterpoint
# - permit                - If the waterpoint is permitted
# - construction_year     - Year the waterpoint was constructed
# - extraction_type       - The kind of extraction the waterpoint uses
# - extraction_type_group - The kind of extraction the waterpoint uses
# - extraction_type_class - The kind of extraction the waterpoint uses
# - management            - How the waterpoint is managed
# - management_group      - How the waterpoint is managed
# - payment               - What the water costs
# - payment_type          - What the water costs
# - water_quality         - The quality of the water
# - quality_group         - The quality of the water
# - quantity              - The quantity of water
# - quantity_group        - The quantity of water
# - source                - The source of the water
# - source_type           - The source of the water
# - source_class          - The source of the water
# - waterpoint_type       - The kind of waterpoint
# - waterpoint_type_group - The kind of waterpoint

# %% [markdown]
# #### Observation
# - There seems to be duplicated columns in the dataframe.
#
# - They have same infomation.
#
# - I will expore that further later

# %% [markdown]
# #### status_group column
#
# There is need for an additional column that rates the condition of the waterpoints as:
#
# - functional - the waterpoint is operational and there are no repairs needed
# - functional needs repair - the waterpoint is operational, but needs repairs
# - non functional - the waterpoint is not operational

# %%
#Check dataframe shapes
print('Train:', train.shape)
print()
print('Test:', test.shape)
# Out:
# Train: (59400, 39)
#
# Test: (14850, 39)

# %%
# Chech train dataframe information
train.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 59400 entries, 69572 to 26348
# Data columns (total 39 columns):
#  #   Column                 Non-Null Count  Dtype
# ---  ------                 --------------  -----
#  0   amount_tsh             59400 non-null  float64
#  1   date_recorded          59400 non-null  object
#  2   funder                 55765 non-null  object
#  3   gps_height             59400 non-null  int64
#  4   installer              55745 non-null  object
#  5   longitude              59400 non-null  float64
#  6   latitude               59400 non-null  float64
#  7   wpt_name               59400 non-null  object
#  8   num_private            59400 non-null  int64
#  9   basin                  59400 non-null  object
#  10  subvillage             59029 non-null  object
#  11  region                 59400 non-null  object
#  12  region_code            59400 non-null  int64
#  13  district_code          59400 non-null  int64
#  14  lga                    59400 non-null  object
#  15  ward                   59400 non-null  object
#  16  population             59400 non-null  int64
#  17  public_meeting         56066 non-null  object
#  18  recorded_by            59400 non-null  object
#  19  scheme_management      55523 non-null  object
#  20  scheme_name            31234 non-null  object
#  21  permit                 56344 non-null  object
#  22  construction_year      59400 non-null  int64
#  23  extraction_type        59400 non-null  object
#  24  extraction_type_group  59400 non-null  object
#  25  extraction_type_class  59400 non-null  object
#  26  management             59400 non-null  object
#  27  management_group       59400 non-null  object
#  28  payment                59400 non-null  object
#  29  payment_type           59400 non-null  object
#  30  water_quality          59400 non-null  object
#  31  quality_group          59400 non-null  object
#  32  quantity               59400 non-null  object
#  33  quantity_group         59400 non-null  object
#  34  source                 59400 non-null  object
#  35  source_type            59400 non-null  object
#  36  source_class           59400 non-null  object
#  37  waterpoint_type        59400 non-null  object
#  38  waterpoint_type_group  59400 non-null  object
# dtypes: float64(3), int64(6), object(30)
# memory usage: 18.1+ MB

# %%
# Check train dataframe description
train.describe().T
# Out:
#                      count         mean          std       min        25%  \
# amount_tsh         59400.0   317.650385  2997.574558   0.00000   0.000000
# gps_height         59400.0   668.297239   693.116350 -90.00000   0.000000
# longitude          59400.0    34.077427     6.567432   0.00000  33.090347
# latitude           59400.0    -5.706033     2.946019 -11.64944  -8.540621
# num_private        59400.0     0.474141    12.236230   0.00000   0.000000
# region_code        59400.0    15.297003    17.587406   1.00000   5.000000
# district_code      59400.0     5.629747     9.633649   0.00000   2.000000
# population         59400.0   179.909983   471.482176   0.00000   0.000000
# construction_year  59400.0  1300.652475   951.620547   0.00000   0.000000
#
#                            50%          75%           max
# amount_tsh            0.000000    20.000000  3.500000e+05
# gps_height          369.000000  1319.250000  2.770000e+03
# longitude            34.908743    37.178387  4.034519e+01
# latitude             -5.021597    -3.326156 -2.000000e-08
# num_private           0.000000     0.000000  1.776000e+03
# region_code          12.000000    17.000000  9.900000e+01
# district_code         3.000000     5.000000  8.000000e+01
# population           25.000000   215.000000  3.050000e+04
# construction_year  1986.000000  2004.000000  2.013000e+03

# %% [markdown]
# # 2. Data Cleaning

# %% [markdown]
# The data cleaning methods to be employed are :
#
# - Duplicates
# - Validity
# - Completeness

# %% [markdown]
# ## 2.1. Duplicates
# - Checking for duplicates in the rows

# %%
train.duplicated().sum()
# Out:
# 37

# %%
#get an overview of the duplicates
train[train.duplicated(keep = False)].head(6)
# Out:
#        amount_tsh date_recorded                  funder  gps_height  \
# id
# 72678         0.0    2013-01-30                     Wvt           0
# 70379         0.0    2011-07-18  Government Of Tanzania           0
# 51403         0.0    2013-02-16                    Dwsp           0
# 7900          0.0    2011-07-18  Government Of Tanzania           0
# 58343         0.0    2013-01-18                     Wvt           0
# 3376          0.0    2012-10-25                    Dwsp           0
#
#         installer  longitude      latitude                     wpt_name  \
# id
# 72678         WVT        0.0 -2.000000e-08                 Wvt Tanzania
# 70379  Government        0.0 -2.000000e-08              Nersing College
# 51403         DWE        0.0 -2.000000e-08                    Serengeti
# 7900   Government        0.0 -2.000000e-08                     Hospital
# 58343         WVT        0.0 -2.000000e-08  Shule Ya Msingi Mwamigagani
# 3376          DWE        0.0 -2.000000e-08                       Wazazi
#
#        num_private          basin  subvillage     region  region_code  \
# id
# 72678            0  Lake Victoria       Ilula  Shinyanga           17
# 70379            0  Lake Victoria      Nyanza     Mwanza           19
# 51403            0  Lake Victoria    Madukani     Mwanza           17
# 7900             0  Lake Victoria      Nyanza     Mwanza           19
# 58343            0  Lake Victoria  Mwalushu B  Shinyanga           17
# 3376             0  Lake Victoria    Madukani     Mwanza           17
#
#        district_code      lga  ... extraction_type_group  \
# id                             ...
# 72678              1  Bariadi  ...               gravity
# 70379              6    Geita  ...               afridev
# 51403              1     Magu  ...                 other
# 7900               6    Geita  ...           submersible
# 58343              1  Bariadi  ...               gravity
# 3376               1     Magu  ...                swn 80
#
#        extraction_type_class  management management_group    payment  \
# id
# 72678                gravity  parastatal       parastatal      other
# 70379               handpump         vwc       user-group  never pay
# 51403                  other         wug       user-group    unknown
# 7900             submersible         vwc       user-group  never pay
# 58343                gravity  parastatal       parastatal  never pay
# 3376                handpump         wug       user-group    unknown
#
#       payment_type water_quality  quality_group      quantity quantity_group  \
# id
# 72678        other          soft           good      seasonal       seasonal
# 70379    never pay          soft           good  insufficient   insufficient
# 51403      unknown          soft           good        enough         enough
# 7900     never pay          soft           good  insufficient   insufficient
# 58343    never pay          soft           good      seasonal       seasonal
# 3376       unknown          soft           good        enough         enough
#
#                      source           source_type source_class  \
# id
# 72678  rainwater harvesting  rainwater harvesting      surface
# 70379           machine dbh              borehole  groundwater
# 51403                 other                 other      unknown
# 7900            machine dbh              borehole  groundwater
# 58343  rainwater harvesting  rainwater harvesting      surface
# 3376           shallow well          shallow well  groundwater
#
#           waterpoint_type waterpoint_type_group
# id
# 72678  communal standpipe    communal standpipe
# 70379           hand pump             hand pump
# 51403               other                 other
# 7900   communal standpipe    communal standpipe
# 58343  communal standpipe    communal standpipe
# 3376            hand pump             hand pump
#
# [6 rows x 39 columns]

# %%
#drop all duplicates
train.drop_duplicates(inplace=True)

# %%
# Confirming all duplicates are dropped
train.duplicated().any()
# Out:
# False

# %% [markdown]
# As mentioned earlier there are columns that seem to have repeated information.
# I will explore these columns to assertain if they are indeed duplicated then drop some of them.

# %%
train.apply(lambda x: len(x.unique()))
# Out:
# amount_tsh                  98
# date_recorded              356
# funder                    1898
# gps_height                2428
# installer                 2146
# longitude                57516
# latitude                 57517
# wpt_name                 37400
# num_private                 65
# basin                        9
# subvillage               19288
# region                      21
# region_code                 27
# district_code               20
# lga                        125
# ward                      2092
# population                1049
# public_meeting               3
# recorded_by                  1
# scheme_management           13
# scheme_name               2697
# permit                       3
# construction_year           55
# extraction_type             18
# extraction_type_group       13
# extraction_type_class        7
# management                  12
# management_group             5
# payment                      7
# payment_type                 7
# water_quality                8
# quality_group                6
# quantity                     5
# quantity_group               5
# source                      10
# source_type                  7
# source_class                 3
# waterpoint_type              7
# waterpoint_type_group        6
# dtype: int64

# %% [markdown]
# #### Waterpoint

# %%
train['waterpoint_type'].value_counts()
# Out:
# communal standpipe             28515
# hand pump                      17466
# other                           6377
# communal standpipe multiple     6099
# improved spring                  783
# cattle trough                    116
# dam                                7
# Name: waterpoint_type, dtype: int64

# %%
train['waterpoint_type_group'].value_counts()
# Out:
# communal standpipe    34614
# hand pump             17466
# other                  6377
# improved spring         783
# cattle trough           116
# dam                       7
# Name: waterpoint_type_group, dtype: int64

# %%
# Both columns have the same data
# Communal standpipe and standpipe multiple are merged in waterpoint type group
# I will drop one of the columns. 
train = train.drop(['waterpoint_type'],axis=1)
test = test.drop(['waterpoint_type'],axis=1)

# %% [markdown]
# #### Source

# %%
train['source'].value_counts()
# Out:
# spring                  17020
# shallow well            16801
# machine dbh             11069
# river                    9612
# rainwater harvesting     2292
# hand dtw                  874
# lake                      763
# dam                       655
# other                     211
# unknown                    66
# Name: source, dtype: int64

# %%
train['source_type'].value_counts()
# Out:
# spring                  17020
# shallow well            16801
# borehole                11943
# river/lake              10375
# rainwater harvesting     2292
# dam                       655
# other                     277
# Name: source_type, dtype: int64

# %%
train['source_class'].value_counts()
# Out:
# groundwater    45764
# surface        13322
# unknown          277
# Name: source_class, dtype: int64

# %%
# Source and source type have similar data 
# Some values are merged in the source type column
# I will drop one of the columns
train = train.drop(['source'],axis=1)
test = test.drop(['source'],axis=1)

# %% [markdown]
# #### Quantity

# %%
train['quantity'].value_counts()
# Out:
# enough          33165
# insufficient    15119
# dry              6243
# seasonal         4047
# unknown           789
# Name: quantity, dtype: int64

# %%
train['quantity_group'].value_counts()
# Out:
# enough          33165
# insufficient    15119
# dry              6243
# seasonal         4047
# unknown           789
# Name: quantity_group, dtype: int64

# %%
# Both columns have the same data
# I will drop one of the columns. 
train = train.drop(['quantity_group'],axis=1)
test = test.drop(['quantity_group'],axis=1)

# %% [markdown]
# #### Quality

# %%
train['water_quality'].value_counts()
# Out:
# soft                  50784
# salty                  4856
# unknown                1873
# milky                   804
# coloured                490
# salty abandoned         339
# fluoride                200
# fluoride abandoned       17
# Name: water_quality, dtype: int64

# %%
train['quality_group'].value_counts()
# Out:
# good        50784
# salty        5195
# unknown      1873
# milky         804
# colored       490
# fluoride      217
# Name: quality_group, dtype: int64

# %%
# Source and source type have similar data 
# Some values are merged in the quality group column
# I will drop one of the columns
train = train.drop(['quality_group'],axis=1)
test = test.drop(['quality_group'],axis=1)

# %% [markdown]
# #### Payment

# %%
train['payment'].value_counts()
# Out:
# never pay                25336
# pay per bucket            8984
# pay monthly               8300
# unknown                   8134
# pay when scheme fails     3914
# pay annually              3642
# other                     1053
# Name: payment, dtype: int64

# %%
train['payment_type'].value_counts()
# Out:
# never pay     25336
# per bucket     8984
# monthly        8300
# unknown        8134
# on failure     3914
# annually       3642
# other          1053
# Name: payment_type, dtype: int64

# %%
# Both columns have the same data
# I will drop one of the columns. 
train = train.drop(['payment'],axis=1)
test = test.drop(['payment'],axis=1)

# %% [markdown]
# #### Management

# %%
train['management'].value_counts()
# Out:
# vwc                 40493
# wug                  6495
# water board          2933
# wua                  2535
# private operator     1971
# parastatal           1765
# water authority       904
# other                 844
# company               685
# unknown               561
# other - school         99
# trust                  78
# Name: management, dtype: int64

# %%
train['management_group'].value_counts()
# Out:
# user-group    52456
# commercial     3638
# parastatal     1765
# other           943
# unknown         561
# Name: management_group, dtype: int64

# %%
# Source and source type have similar data 
# Some values are merged in the management group column
# I will drop one of the columns
train = train.drop(['management'],axis=1)
test = test.drop(['management'],axis=1)

# %% [markdown]
# #### Extraction

# %%
train['extraction_type'].value_counts()
# Out:
# gravity                      26775
# nira/tanira                   8143
# other                         6427
# submersible                   4759
# swn 80                        3663
# mono                          2865
# india mark ii                 2398
# afridev                       1769
# ksb                           1413
# other - rope pump              451
# other - swn 81                 229
# windmill                       117
# india mark iii                  97
# cemo                            90
# other - play pump               85
# walimi                          48
# climax                          32
# other - mkulima/shinyanga        2
# Name: extraction_type, dtype: int64

# %%
train['extraction_type_group'].value_counts()
# Out:
# gravity            26775
# nira/tanira         8143
# other               6427
# submersible         6172
# swn 80              3663
# mono                2865
# india mark ii       2398
# afridev             1769
# rope pump            451
# other handpump       364
# other motorpump      122
# wind-powered         117
# india mark iii        97
# Name: extraction_type_group, dtype: int64

# %%
train['extraction_type_class'].value_counts()
# Out:
# gravity         26775
# handpump        16434
# other            6427
# submersible      6172
# motorpump        2987
# rope pump         451
# wind-powered      117
# Name: extraction_type_class, dtype: int64

# %%
# Source and source type have similar data 
# Some values are merged in the extraction type class column
# I will drop two of the columns
train = train.drop(['extraction_type', 'extraction_type_group'],axis=1)
test = test.drop(['extraction_type', 'extraction_type_group'],axis=1)

# %% [markdown]
# #### Geography

# %%
# There are too many columns representing geographical data
# e.g. gps_height, longitude, latitude, region_code and district_code
# These are less likely to add any predictive power to the model
# I will drop some of these columns
train = train.drop(['gps_height', 'longitude', 'latitude', 'region_code', 'district_code',
                    'lga','region','ward'], axis=1)

test = test.drop(['gps_height', 'longitude', 'latitude', 'region_code', 'district_code',
                  'lga','region','ward'], axis=1)

# %% [markdown]
# ## 2.2. Validity
# - I will check whether the data conforms to the constraints applied by the business rules

# %% [markdown]
# #### num_private and wpt_name
#
# - 'num_private' hasn't been given a description on Driven Data, it appears to be superflous.
# - 'wpt_name' gives only waterpoint name. It does not seem relevant in prediction
# -  I will drop these columns

# %%
train = train.drop(['num_private', 'wpt_name'], axis=1)

test = test.drop(['num_private', 'wpt_name'], axis=1)

# %% [markdown]
# #### Construction Year
#
# - I will turn construction_year into a categorical column containing the following values: '60s', '70s','80s', '90s, '00s', '10s', 'unknown'.

# %%
def construction_grouping(row):
    if row['construction_year'] >= 1960 and row['construction_year'] < 1970:
        return '60s'
    elif row['construction_year'] >= 1970 and row['construction_year'] < 1980:
        return '70s'
    elif row['construction_year'] >= 1980 and row['construction_year'] < 1990:
        return '80s'
    elif row['construction_year'] >= 1990 and row['construction_year'] < 2000:
        return '90s'
    elif row['construction_year'] >= 2000 and row['construction_year'] < 2010:
        return '00s'
    elif row['construction_year'] >= 2010:
        return '10s'
    else:
        return 'unknown'
    
train['construction_year'] = train.apply(lambda row: construction_grouping(row), axis=1)
test['construction_year'] = test.apply(lambda row: construction_grouping(row), axis=1)

# %% [markdown]
# #### Date recorded
# - I will convert 'date_recorded' into records of days since it was recorded

# %%
test.date_recorded = pd.datetime(2013, 12, 3) - pd.to_datetime(test.date_recorded)
test.columns = ['days_since_recorded' if x=='date_recorded' else x for x in test.columns]
test.days_since_recorded = test.days_since_recorded.astype('timedelta64[D]').astype(int)

train.date_recorded = pd.datetime(2013, 12, 3) - pd.to_datetime(train.date_recorded)
train.columns = ['days_since_recorded' if x=='date_recorded' else x for x in train.columns]
train.days_since_recorded = train.days_since_recorded.astype('timedelta64[D]').astype(int)

# %% [markdown]
# ## 2.2 Completeness

# %%
def missing_data(df):
    missing_data = df.isna().sum()
    missing_data = missing_data[missing_data>0]
    return missing_data

# %%
# print missing columns on training test
missing_data(train)
# Out:
# funder                3635
# installer             3655
# subvillage             371
# public_meeting        3314
# scheme_management     3877
# scheme_name          28138
# permit                3056
# dtype: int64

# %%
# Print missing columns on test set
missing_data(test)
# Out:
# funder                869
# installer             877
# subvillage             99
# public_meeting        821
# scheme_management     969
# scheme_name          7092
# permit                737
# dtype: int64

# %% [markdown]
# To get a better understanding of how to deal with the missing values, I will explore the columns further.

# %% [markdown]
# #### funder column

# %%
# get value counts
train['funder'].value_counts()
# Out:
# Government Of Tanzania    9076
# Danida                    3114
# Hesawa                    2198
# Rwssp                     1372
# World Bank                1349
#                           ...
# Serikaru                     1
# Zao Water Spring X           1
# Seleman Rashid               1
# Nyitamboka                   1
# Unicet                       1
# Name: funder, Length: 1897, dtype: int64

# %%
# I will group the column into 6 categories. The top 5 value counts and the rest in other

def funder_grouping(dataframe):
    if dataframe['funder'] == 'Government Of Tanzania':
        return 'government'
    elif dataframe['funder'] == 'Danida':
        return 'danida'
    elif dataframe['funder'] == 'Hesawa':
        return 'hesawa'
    elif dataframe['funder'] == 'Rwssp':
        return 'rwssp'
    elif dataframe['funder'] == 'World Bank':
        return 'world_bank'    
    else:
        return 'other'
    
train['funder'] = train.apply(lambda row: funder_grouping(row), axis=1)
test['funder'] = test.apply(lambda row: funder_grouping(row), axis=1)

# %% [markdown]
# #### installer column

# %%
#installer
train['installer'].value_counts()
# Out:
# DWE            17385
# Government      1818
# RWE             1205
# Commu           1060
# DANIDA          1050
#                ...
# Sh                 1
# Benjamin           1
# CARE/CIPRO         1
# KDC                1
# J LH CO LTD        1
# Name: installer, Length: 2145, dtype: int64

# %%
# I will group the column into 6 categories. The top 5 value counts and the rest in other
def installer_grouping(dataframe):
    if dataframe['installer'] == 'DWE':
        return 'dwe'
    elif dataframe['installer'] == 'Government':
        return 'government'
    elif dataframe['installer'] == 'RWE':
        return 'rwe'
    elif dataframe['installer'] == 'Commu':
        return 'commu'
    elif dataframe['installer'] == 'DANIDA':
        return 'danida'    
    else:
        return 'other'
    
train['installer'] = train.apply(lambda row: installer_grouping(row), axis=1)
test['installer'] = test.apply(lambda row: installer_grouping(row), axis=1)

# %% [markdown]
# #### subvillage

# %%
# It is harder to divide this column since we have no dominating values
train['subvillage'].value_counts()

# probably better off dropping this column
# Out:
# Shuleni             505
# Madukani            503
# Majengo             502
# Kati                373
# Mtakuja             262
#                    ...
# Mabangalaa            1
# Chamasejo             1
# Kwemware              1
# Ruhimbila             1
# Luhota Secondary      1
# Name: subvillage, Length: 19287, dtype: int64

# %%
train=train.drop(['subvillage'],axis = 1)
test=test.drop(['subvillage'],axis = 1)

# %% [markdown]
# #### public meeting

# %%
#public_meeting
train['public_meeting'].value_counts()
# Out:
# True     50995
# False     5054
# Name: public_meeting, dtype: int64

# %%
# There are more trues that Falses. 
# I will fill the missing values with True
train.public_meeting = train.public_meeting.fillna('Unknown')
test.public_meeting = test.public_meeting.fillna('Unknown')

# %% [markdown]
# #### scheme management

# %%
#Scheme Management
train['scheme_management'].value_counts()
# Out:
# VWC                 36779
# WUG                  5186
# Water authority      3153
# WUA                  2883
# Water Board          2748
# Parastatal           1677
# Private operator     1063
# Company              1061
# Other                 766
# SWC                    97
# Trust                  72
# None                    1
# Name: scheme_management, dtype: int64

# %%
# There are too many categories in this column
# I will divide it into 6 categories with 5 being the top 5 and the rest in other

def scheme_grouping(row):
    '''Keep top 5 values and set the rest to 'other'. '''
    if row['scheme_management'] == 'VWC':
        return 'vwc'
    elif row['scheme_management'] == 'WUG':
        return 'wug'
    elif row['scheme_management'] == 'Water authority':
        return 'water_authority'
    elif row['scheme_management'] == 'WUA':
        return 'wua'
    elif row['scheme_management'] == 'Water Board':
        return 'water_board'
    else:
        return 'other'

train['scheme_management'] = train.apply(lambda row: scheme_grouping(row), axis=1)
test['scheme_management'] = test.apply(lambda row: scheme_grouping(row), axis=1)

# %% [markdown]
# #### scheme name

# %%
#Scheme name
train['scheme_name'].value_counts()
# Out:
# K                                     682
# None                                  644
# Borehole                              545
# Chalinze wate                         405
# M                                     400
#                                      ...
# lgongolo gravity water sche             1
# Upper RUVU                              1
# BL Lamaungu                             1
# Kibohelo forest                         1
# Flood water sustainability project      1
# Name: scheme_name, Length: 2696, dtype: int64

# %%
len(train.scheme_name.unique())
# Out:
# 2697

# %%
# It is harder to divide this column since we have no dominating values
# its better to drop the column
train = train.drop('scheme_name', axis = 1)
test = test.drop('scheme_name', axis = 1)

# %% [markdown]
# #### permit

# %%
#permit
train['permit'].value_counts()
# Out:
# True     38838
# False    17469
# Name: permit, dtype: int64

# %%
# There are more trues that Falses. 
# I will fill the missing values with True
train.permit = train.permit.fillna('Unknown')
test.permit = test.permit.fillna('Unknown')

# %% [markdown]
# Checking for missing values again in both the train and test data

# %%
missing_data(train)
# Out:
# Series([], dtype: int64)

# %%
missing_data(test)
# Out:
# Series([], dtype: int64)

# %% [markdown]
# Great! There are no more missing values

# %%
train
# Out:
#        amount_tsh  days_since_recorded      funder installer  \
# id
# 69572      6000.0                  995       other     other
# 8776          0.0                  272       other     other
# 34310        25.0                  281       other     other
# 67743         0.0                  309       other     other
# 19728         0.0                  874       other     other
# ...           ...                  ...         ...       ...
# 60739        10.0                  214       other     other
# 27263      4700.0                  941       other     other
# 37057         0.0                  967       other     other
# 31282         0.0                 1001       other     other
# 26348         0.0                  986  world_bank     other
#
#                          basin  population public_meeting  \
# id
# 69572               Lake Nyasa         109           True
# 8776             Lake Victoria         280        Unknown
# 34310                  Pangani         250           True
# 67743  Ruvuma / Southern Coast          58           True
# 19728            Lake Victoria           0           True
# ...                        ...         ...            ...
# 60739                  Pangani         125           True
# 27263                   Rufiji          56           True
# 37057                   Rufiji           0           True
# 31282                   Rufiji           0           True
# 26348              Wami / Ruvu         150           True
#
#                    recorded_by scheme_management permit construction_year  \
# id
# 69572  GeoData Consultants Ltd               vwc  False               90s
# 8776   GeoData Consultants Ltd             other   True               10s
# 34310  GeoData Consultants Ltd               vwc   True               00s
# 67743  GeoData Consultants Ltd               vwc   True               80s
# 19728  GeoData Consultants Ltd             other   True           unknown
# ...                        ...               ...    ...               ...
# 60739  GeoData Consultants Ltd       water_board   True               90s
# 27263  GeoData Consultants Ltd               vwc   True               90s
# 37057  GeoData Consultants Ltd               vwc  False           unknown
# 31282  GeoData Consultants Ltd               vwc   True           unknown
# 26348  GeoData Consultants Ltd               vwc   True               00s
#
#       extraction_type_class management_group payment_type water_quality  \
# id
# 69572               gravity       user-group     annually          soft
# 8776                gravity       user-group    never pay          soft
# 34310               gravity       user-group   per bucket          soft
# 67743           submersible       user-group    never pay          soft
# 19728               gravity            other    never pay          soft
# ...                     ...              ...          ...           ...
# 60739               gravity       user-group   per bucket          soft
# 27263               gravity       user-group     annually          soft
# 37057              handpump       user-group      monthly      fluoride
# 31282              handpump       user-group    never pay          soft
# 26348              handpump       user-group   on failure         salty
#
#            quantity           source_type source_class waterpoint_type_group
# id
# 69572        enough                spring  groundwater    communal standpipe
# 8776   insufficient  rainwater harvesting      surface    communal standpipe
# 34310        enough                   dam      surface    communal standpipe
# 67743           dry              borehole  groundwater    communal standpipe
# 19728      seasonal  rainwater harvesting      surface    communal standpipe
# ...             ...                   ...          ...                   ...
# 60739        enough                spring  groundwater    communal standpipe
# 27263        enough            river/lake      surface    communal standpipe
# 37057        enough              borehole  groundwater             hand pump
# 31282  insufficient          shallow well  groundwater             hand pump
# 26348        enough          shallow well  groundwater             hand pump
#
# [59363 rows x 19 columns]

# %% [markdown]
# # 3. Exploratory Data Analysis (EDA)

# %% [markdown]
# ## 3.1 Multicollinearity

# %%
cor = train.corr()
plt.figure(figsize = (15,10))
sns.heatmap(cor.round(3),annot = True,cmap = 'coolwarm')
plt.show()

# %% [markdown]
# - Features do not have a high collinerity amongst themselves
# - This is good data

# %%
train.hist(figsize = (20,18));
